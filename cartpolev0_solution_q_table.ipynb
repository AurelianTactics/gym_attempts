# %% [markdown]
# # Solution to OpenAI Gym's Cartpole Version 0
#
# * Goal is to balance a pole on a moving cart.
# * Game is considered solved if able to obtain an average reward of 195 over 100 consecutive games.
# * Solution below is a simple Q table look up using incremental update as described in Chapter 2.5 of Reinforcement Learning: An Introduction by Sutton and Barto
# * Exploration is episolon greedy with epsilon starting at 0.99 and linearly decaying (with a minimum value of 0.05 during training)

# %%
import gym
import numpy as np
import random

env = gym.make('CartPole-v0')

Q                = {} #the Q-table
learningRate     = 0.1 #amount of update
randomActionRate = 0.99 
totalReward      = 0
episodes = 100000 #number of episodes to find Q table values
observation_round = 100 

for i_episode in range(episodes):
    observation = env.reset()
    episodeReward = 0

    for t in range(300):
        if t >= 199:
            print("200 successfull movements {}".format(i_episode))
        # Choose Action
        old_observation = observation #old_observation is used with reward from action to update Q table
        action = env.action_space.sample()
        
        random_threshold = randomActionRate - i_episode/episodes
        if random_threshold < 0.05:
            random_threshold = 0.05
            
        #choosing best Q table action if random value exceeds threshold, if not action is randomized (in line above)
        if(random.random() > random_threshold):
            bestReward = 0
            for possibleAction in [0, 1]:
                temp_state = []
                for i in observation:
                    temp_state.append(round(i*observation_round,0))
                temp_state.append(possibleAction)

                possibleReward = Q.get(tuple(temp_state[2:]),0.)
                if(possibleReward > bestReward):
                    action = possibleAction
                    bestReward = possibleReward

        # Update Q State
        observation, reward, done, info = env.step(action)
        
        temp_state = []
        for i in old_observation:
            temp_state.append(round(i*observation_round,0))
        temp_state.append(action)
        state = tuple(temp_state[2:]) #only using 2 of the four observations: (pole angle and pole velocity)
        
        #seeing whether going left or right with current obesrvation leads to a higher expected reward
        temp_state2 = []
        temp_state3 = []
        for i in observation:
            temp_state2.append(round(i*observation_round,0))
            temp_state3.append(round(i*observation_round,0))
        temp_state2.append(0)
        temp_state3.append(1)
        
        reward_0 = Q.get(tuple(temp_state2[2:]),0.)
        reward_1 = Q.get(tuple(temp_state3[2:]),0.)
        next_best_reward = max(reward_0,reward_1)
            
        if done:
            #negative rewards for states that lead to failure
            if t < 199:
                Q[state] = Q.get(state, 0) + learningRate * -1.
            if i_episode % 10 == 0:
                print("Episode finished after {} timesteps with {} reward".format(t+1, episodeReward),random_threshold)
            break
        
        #update the Q state
        Q[state] = Q.get(state, 0) + learningRate * ( reward + next_best_reward - Q.get(state, 0.) ) 

        episodeReward += reward
    
    totalReward += episodeReward

print("Total Reward: {}".format(totalReward), totalReward/episodes)
# Out:
# [2017-07-10 10:35:51,961] Making new env: CartPole-v0
# Episode finished after 10 timesteps with 9.0 reward 0.99
# Episode finished after 21 timesteps with 20.0 reward 0.9899
# Episode finished after 18 timesteps with 17.0 reward 0.9898
# Episode finished after 14 timesteps with 13.0 reward 0.9897
# Episode finished after 34 timesteps with 33.0 reward 0.9896
# Episode finished after 10 timesteps with 9.0 reward 0.9895
# Episode finished after 13 timesteps with 12.0 reward 0.9894
# Episode finished after 21 timesteps with 20.0 reward 0.9893
# Episode finished after 20 timesteps with 19.0 reward 0.9892
# Episode finished after 28 timesteps with 27.0 reward 0.9891
# Episode finished after 24 timesteps with 23.0 reward 0.989
# Episode finished after 31 timesteps with 30.0 reward 0.9889
# Episode finished after 28 timesteps with 27.0 reward 0.9888
# Episode finished after 33 timesteps with 32.0 reward 0.9887
# Episode finished after 36 timesteps with 35.0 reward 0.9886
# Episode finished after 44 timesteps with 43.0 reward 0.9885
# Episode finished after 10 timesteps with 9.0 reward 0.9884
# Episode finished after 10 timesteps with 9.0 reward 0.9883
# Episode finished after 21 timesteps with 20.0 reward 0.9882
# Episode finished after 16 timesteps with 15.0 reward 0.9881
# Episode finished after 13 timesteps with 12.0 reward 0.988
# Episode finished after 14 timesteps with 13.0 reward 0.9879
# Episode finished after 16 timesteps with 15.0 reward 0.9878
# Episode finished after 66 timesteps with 65.0 reward 0.9877
# Episode finished after 13 timesteps with 12.0 reward 0.9876
# Episode finished after 21 timesteps with 20.0 reward 0.9875
# Episode finished after 12 timesteps with 11.0 reward 0.9873999999999999
# Episode finished after 20 timesteps with 19.0 reward 0.9873
# Episode finished after 59 timesteps with 58.0 reward 0.9872
# Episode finished after 55 timesteps with 54.0 reward 0.9871
# Episode finished after 33 timesteps with 32.0 reward 0.987
# Episode finished after 25 timesteps with 24.0 reward 0.9869
# Episode finished after 21 timesteps with 20.0 reward 0.9868
# Episode finished after 24 timesteps with 23.0 reward 0.9867
# Episode finished after 15 timesteps with 14.0 reward 0.9866
# Episode finished after 19 timesteps with 18.0 reward 0.9865
# Episode finished after 37 timesteps with 36.0 reward 0.9863999999999999
# Episode finished after 14 timesteps with 13.0 reward 0.9863
# Episode finished after 11 timesteps with 10.0 reward 0.9862
# Episode finished after 14 timesteps with 13.0 reward 0.9861
# Episode finished after 13 timesteps with 12.0 reward 0.986
# Episode finished after 46 timesteps with 45.0 reward 0.9859
# Episode finished after 15 timesteps with 14.0 reward 0.9858
# Episode finished after 9 timesteps with 8.0 reward 0.9857
# Episode finished after 26 timesteps with 25.0 reward 0.9856
# Episode finished after 35 timesteps with 34.0 reward 0.9855
# Episode finished after 15 timesteps with 14.0 reward 0.9853999999999999
# Episode finished after 17 timesteps with 16.0 reward 0.9853
# Episode finished after 12 timesteps with 11.0 reward 0.9852
# Episode finished after 14 timesteps with 13.0 reward 0.9851
# Episode finished after 28 timesteps with 27.0 reward 0.985
# Episode finished after 29 timesteps with 28.0 reward 0.9849
# Episode finished after 41 timesteps with 40.0 reward 0.9848
# Episode finished after 13 timesteps with 12.0 reward 0.9847
# Episode finished after 16 timesteps with 15.0 reward 0.9846
# Episode finished after 17 timesteps with 16.0 reward 0.9845
# Episode finished after 15 timesteps with 14.0 reward 0.9843999999999999
# Episode finished after 13 timesteps with 12.0 reward 0.9843
# Episode finished after 11 timesteps with 10.0 reward 0.9842
# Episode finished after 17 timesteps with 16.0 reward 0.9841
# Episode finished after 12 timesteps with 11.0 reward 0.984
# Episode finished after 19 timesteps with 18.0 reward 0.9839
# Episode finished after 17 timesteps with 16.0 reward 0.9838
# Episode finished after 21 timesteps with 20.0 reward 0.9837
# Episode finished after 11 timesteps with 10.0 reward 0.9836
# Episode finished after 19 timesteps with 18.0 reward 0.9835
# Episode finished after 41 timesteps with 40.0 reward 0.9833999999999999
# Episode finished after 19 timesteps with 18.0 reward 0.9833
# Episode finished after 12 timesteps with 11.0 reward 0.9832
# Episode finished after 30 timesteps with 29.0 reward 0.9831
# Episode finished after 15 timesteps with 14.0 reward 0.983
# Episode finished after 22 timesteps with 21.0 reward 0.9829
# Episode finished after 12 timesteps with 11.0 reward 0.9828
# Episode finished after 25 timesteps with 24.0 reward 0.9827
# Episode finished after 30 timesteps with 29.0 reward 0.9826
# Episode finished after 20 timesteps with 19.0 reward 0.9825
# Episode finished after 11 timesteps with 10.0 reward 0.9823999999999999
# Episode finished after 18 timesteps with 17.0 reward 0.9823
# Episode finished after 18 timesteps with 17.0 reward 0.9822
# Episode finished after 27 timesteps with 26.0 reward 0.9821
# Episode finished after 64 timesteps with 63.0 reward 0.982
# Episode finished after 47 timesteps with 46.0 reward 0.9819
# Episode finished after 13 timesteps with 12.0 reward 0.9818
# Episode finished after 10 timesteps with 9.0 reward 0.9817
# Episode finished after 12 timesteps with 11.0 reward 0.9816
# Episode finished after 16 timesteps with 15.0 reward 0.9815
# Episode finished after 10 timesteps with 9.0 reward 0.9813999999999999
# Episode finished after 14 timesteps with 13.0 reward 0.9813
# Episode finished after 13 timesteps with 12.0 reward 0.9812
# Episode finished after 16 timesteps with 15.0 reward 0.9811
# Episode finished after 43 timesteps with 42.0 reward 0.981
# Episode finished after 21 timesteps with 20.0 reward 0.9809
# Episode finished after 13 timesteps with 12.0 reward 0.9808
# Episode finished after 20 timesteps with 19.0 reward 0.9807
# Episode finished after 10 timesteps with 9.0 reward 0.9806
# Episode finished after 13 timesteps with 12.0 reward 0.9805
# Episode finished after 24 timesteps with 23.0 reward 0.9803999999999999
# Episode finished after 15 timesteps with 14.0 reward 0.9803
# Episode finished after 37 timesteps with 36.0 reward 0.9802
# Episode finished after 17 timesteps with 16.0 reward 0.9801
# Episode finished after 13 timesteps with 12.0 reward 0.98
# Episode finished after 11 timesteps with 10.0 reward 0.9799
# Episode finished after 26 timesteps with 25.0 reward 0.9798
# Episode finished after 36 timesteps with 35.0 reward 0.9797
# Episode finished after 17 timesteps with 16.0 reward 0.9796
# Episode finished after 15 timesteps with 14.0 reward 0.9795
# Episode finished after 15 timesteps with 14.0 reward 0.9793999999999999
# Episode finished after 20 timesteps with 19.0 reward 0.9793
# Episode finished after 38 timesteps with 37.0 reward 0.9792
# Episode finished after 13 timesteps with 12.0 reward 0.9791
# Episode finished after 32 timesteps with 31.0 reward 0.979
# Episode finished after 33 timesteps with 32.0 reward 0.9789
# Episode finished after 18 timesteps with 17.0 reward 0.9788
# Episode finished after 36 timesteps with 35.0 reward 0.9787
# Episode finished after 24 timesteps with 23.0 reward 0.9786
# Episode finished after 10 timesteps with 9.0 reward 0.9785
# Episode finished after 17 timesteps with 16.0 reward 0.9783999999999999
# Episode finished after 20 timesteps with 19.0 reward 0.9783
# Episode finished after 10 timesteps with 9.0 reward 0.9782
# Episode finished after 23 timesteps with 22.0 reward 0.9781
# Episode finished after 26 timesteps with 25.0 reward 0.978
# Episode finished after 11 timesteps with 10.0 reward 0.9779
# Episode finished after 17 timesteps with 16.0 reward 0.9778
# Episode finished after 76 timesteps with 75.0 reward 0.9777
# Episode finished after 11 timesteps with 10.0 reward 0.9776
# Episode finished after 16 timesteps with 15.0 reward 0.9775
# Episode finished after 13 timesteps with 12.0 reward 0.9774
# Episode finished after 19 timesteps with 18.0 reward 0.9773
# Episode finished after 21 timesteps with 20.0 reward 0.9772
# Episode finished after 61 timesteps with 60.0 reward 0.9771
# Episode finished after 14 timesteps with 13.0 reward 0.977
# Episode finished after 20 timesteps with 19.0 reward 0.9769
# Episode finished after 35 timesteps with 34.0 reward 0.9768
# Episode finished after 14 timesteps with 13.0 reward 0.9767
# Episode finished after 16 timesteps with 15.0 reward 0.9766
# Episode finished after 34 timesteps with 33.0 reward 0.9765
# Episode finished after 15 timesteps with 14.0 reward 0.9764
# Episode finished after 16 timesteps with 15.0 reward 0.9763
# Episode finished after 10 timesteps with 9.0 reward 0.9762
# Episode finished after 10 timesteps with 9.0 reward 0.9761
# Episode finished after 9 timesteps with 8.0 reward 0.976
# Episode finished after 21 timesteps with 20.0 reward 0.9759
# Episode finished after 45 timesteps with 44.0 reward 0.9758
# Episode finished after 21 timesteps with 20.0 reward 0.9757
# Episode finished after 12 timesteps with 11.0 reward 0.9756
# Episode finished after 38 timesteps with 37.0 reward 0.9755
# Episode finished after 38 timesteps with 37.0 reward 0.9754
# Episode finished after 72 timesteps with 71.0 reward 0.9753
# Episode finished after 22 timesteps with 21.0 reward 0.9752
# Episode finished after 9 timesteps with 8.0 reward 0.9751
# Episode finished after 24 timesteps with 23.0 reward 0.975
# Episode finished after 38 timesteps with 37.0 reward 0.9749
# Episode finished after 23 timesteps with 22.0 reward 0.9748
# Episode finished after 48 timesteps with 47.0 reward 0.9747
# Episode finished after 24 timesteps with 23.0 reward 0.9746
# Episode finished after 30 timesteps with 29.0 reward 0.9745
# Episode finished after 12 timesteps with 11.0 reward 0.9744
# Episode finished after 61 timesteps with 60.0 reward 0.9742999999999999
# Episode finished after 18 timesteps with 17.0 reward 0.9742
# Episode finished after 25 timesteps with 24.0 reward 0.9741
# Episode finished after 25 timesteps with 24.0 reward 0.974
# Episode finished after 14 timesteps with 13.0 reward 0.9739
# Episode finished after 49 timesteps with 48.0 reward 0.9738
# Episode finished after 35 timesteps with 34.0 reward 0.9737
# Episode finished after 11 timesteps with 10.0 reward 0.9736
# Episode finished after 11 timesteps with 10.0 reward 0.9735
# Episode finished after 26 timesteps with 25.0 reward 0.9734
# Episode finished after 33 timesteps with 32.0 reward 0.9732999999999999
# Episode finished after 10 timesteps with 9.0 reward 0.9732
# Episode finished after 13 timesteps with 12.0 reward 0.9731
# Episode finished after 19 timesteps with 18.0 reward 0.973
# Episode finished after 21 timesteps with 20.0 reward 0.9729
# Episode finished after 17 timesteps with 16.0 reward 0.9728
# Episode finished after 31 timesteps with 30.0 reward 0.9727
# Episode finished after 9 timesteps with 8.0 reward 0.9726
# Episode finished after 20 timesteps with 19.0 reward 0.9725
# Episode finished after 34 timesteps with 33.0 reward 0.9724
# Episode finished after 14 timesteps with 13.0 reward 0.9722999999999999
# Episode finished after 29 timesteps with 28.0 reward 0.9722
# Episode finished after 12 timesteps with 11.0 reward 0.9721
# Episode finished after 36 timesteps with 35.0 reward 0.972
# Episode finished after 40 timesteps with 39.0 reward 0.9719
# Episode finished after 21 timesteps with 20.0 reward 0.9718
# Episode finished after 27 timesteps with 26.0 reward 0.9717
# Episode finished after 15 timesteps with 14.0 reward 0.9716
# Episode finished after 14 timesteps with 13.0 reward 0.9715
# Episode finished after 15 timesteps with 14.0 reward 0.9714
# Episode finished after 26 timesteps with 25.0 reward 0.9712999999999999
# Episode finished after 29 timesteps with 28.0 reward 0.9712
# Episode finished after 53 timesteps with 52.0 reward 0.9711
# Episode finished after 27 timesteps with 26.0 reward 0.971
# Episode finished after 14 timesteps with 13.0 reward 0.9709
# Episode finished after 23 timesteps with 22.0 reward 0.9708
# Episode finished after 9 timesteps with 8.0 reward 0.9707
# Episode finished after 27 timesteps with 26.0 reward 0.9706
# Episode finished after 34 timesteps with 33.0 reward 0.9705
# Episode finished after 41 timesteps with 40.0 reward 0.9704
# Episode finished after 13 timesteps with 12.0 reward 0.9702999999999999
# Episode finished after 22 timesteps with 21.0 reward 0.9702
# Episode finished after 43 timesteps with 42.0 reward 0.9701
# Episode finished after 10 timesteps with 9.0 reward 0.97
# Episode finished after 26 timesteps with 25.0 reward 0.9699
# Episode finished after 11 timesteps with 10.0 reward 0.9698
# Episode finished after 25 timesteps with 24.0 reward 0.9697
# Episode finished after 31 timesteps with 30.0 reward 0.9696
# Episode finished after 12 timesteps with 11.0 reward 0.9695
# Episode finished after 19 timesteps with 18.0 reward 0.9694
# Episode finished after 9 timesteps with 8.0 reward 0.9692999999999999
# Episode finished after 22 timesteps with 21.0 reward 0.9692
# Episode finished after 24 timesteps with 23.0 reward 0.9691
# Episode finished after 37 timesteps with 36.0 reward 0.969
# Episode finished after 13 timesteps with 12.0 reward 0.9689
# Episode finished after 15 timesteps with 14.0 reward 0.9688
# Episode finished after 26 timesteps with 25.0 reward 0.9687
# Episode finished after 24 timesteps with 23.0 reward 0.9686
# Episode finished after 21 timesteps with 20.0 reward 0.9685
# Episode finished after 11 timesteps with 10.0 reward 0.9684
# Episode finished after 34 timesteps with 33.0 reward 0.9682999999999999
# Episode finished after 21 timesteps with 20.0 reward 0.9682
# Episode finished after 15 timesteps with 14.0 reward 0.9681
# Episode finished after 27 timesteps with 26.0 reward 0.968
# Episode finished after 16 timesteps with 15.0 reward 0.9679
# Episode finished after 19 timesteps with 18.0 reward 0.9678
# Episode finished after 27 timesteps with 26.0 reward 0.9677
# Episode finished after 16 timesteps with 15.0 reward 0.9676
# Episode finished after 11 timesteps with 10.0 reward 0.9675
# Episode finished after 21 timesteps with 20.0 reward 0.9674
# Episode finished after 16 timesteps with 15.0 reward 0.9672999999999999
# Episode finished after 32 timesteps with 31.0 reward 0.9672
# Episode finished after 12 timesteps with 11.0 reward 0.9671
# Episode finished after 34 timesteps with 33.0 reward 0.967
# Episode finished after 19 timesteps with 18.0 reward 0.9669
# Episode finished after 17 timesteps with 16.0 reward 0.9668
# Episode finished after 32 timesteps with 31.0 reward 0.9667
# Episode finished after 17 timesteps with 16.0 reward 0.9666
# Episode finished after 17 timesteps with 16.0 reward 0.9665
# Episode finished after 19 timesteps with 18.0 reward 0.9664
# Episode finished after 16 timesteps with 15.0 reward 0.9662999999999999
# Episode finished after 31 timesteps with 30.0 reward 0.9662
# Episode finished after 21 timesteps with 20.0 reward 0.9661
# Episode finished after 14 timesteps with 13.0 reward 0.966
# Episode finished after 53 timesteps with 52.0 reward 0.9659
# Episode finished after 11 timesteps with 10.0 reward 0.9658
# Episode finished after 13 timesteps with 12.0 reward 0.9657
# Episode finished after 11 timesteps with 10.0 reward 0.9656
# Episode finished after 16 timesteps with 15.0 reward 0.9655
# Episode finished after 29 timesteps with 28.0 reward 0.9654
# Episode finished after 15 timesteps with 14.0 reward 0.9653
# Episode finished after 22 timesteps with 21.0 reward 0.9652
# Episode finished after 11 timesteps with 10.0 reward 0.9651
# Episode finished after 20 timesteps with 19.0 reward 0.965
# Episode finished after 16 timesteps with 15.0 reward 0.9649
# Episode finished after 15 timesteps with 14.0 reward 0.9648
# Episode finished after 30 timesteps with 29.0 reward 0.9647
# Episode finished after 13 timesteps with 12.0 reward 0.9646
# Episode finished after 52 timesteps with 51.0 reward 0.9645
# Episode finished after 35 timesteps with 34.0 reward 0.9644
# Episode finished after 12 timesteps with 11.0 reward 0.9642999999999999
# Episode finished after 24 timesteps with 23.0 reward 0.9642
# Episode finished after 35 timesteps with 34.0 reward 0.9641
# Episode finished after 19 timesteps with 18.0 reward 0.964
# Episode finished after 12 timesteps with 11.0 reward 0.9639
# Episode finished after 22 timesteps with 21.0 reward 0.9638
# Episode finished after 23 timesteps with 22.0 reward 0.9637
# Episode finished after 24 timesteps with 23.0 reward 0.9636
# Episode finished after 12 timesteps with 11.0 reward 0.9635
# Episode finished after 19 timesteps with 18.0 reward 0.9634
# Episode finished after 13 timesteps with 12.0 reward 0.9633
# Episode finished after 13 timesteps with 12.0 reward 0.9632
# Episode finished after 20 timesteps with 19.0 reward 0.9631
# Episode finished after 11 timesteps with 10.0 reward 0.963
# Episode finished after 14 timesteps with 13.0 reward 0.9629
# Episode finished after 16 timesteps with 15.0 reward 0.9628
# Episode finished after 16 timesteps with 15.0 reward 0.9627
# Episode finished after 36 timesteps with 35.0 reward 0.9626
# Episode finished after 20 timesteps with 19.0 reward 0.9625
# Episode finished after 77 timesteps with 76.0 reward 0.9624
# Episode finished after 55 timesteps with 54.0 reward 0.9623
# Episode finished after 15 timesteps with 14.0 reward 0.9621999999999999
# Episode finished after 29 timesteps with 28.0 reward 0.9621
# Episode finished after 31 timesteps with 30.0 reward 0.962
# Episode finished after 18 timesteps with 17.0 reward 0.9619
# Episode finished after 24 timesteps with 23.0 reward 0.9618
# Episode finished after 28 timesteps with 27.0 reward 0.9617
# Episode finished after 16 timesteps with 15.0 reward 0.9616
# Episode finished after 11 timesteps with 10.0 reward 0.9615
# Episode finished after 15 timesteps with 14.0 reward 0.9614
# Episode finished after 16 timesteps with 15.0 reward 0.9613
# Episode finished after 23 timesteps with 22.0 reward 0.9611999999999999
# Episode finished after 10 timesteps with 9.0 reward 0.9611
# Episode finished after 9 timesteps with 8.0 reward 0.961
# Episode finished after 10 timesteps with 9.0 reward 0.9609
# Episode finished after 25 timesteps with 24.0 reward 0.9608
# Episode finished after 13 timesteps with 12.0 reward 0.9607
# Episode finished after 19 timesteps with 18.0 reward 0.9606
# Episode finished after 63 timesteps with 62.0 reward 0.9605
# Episode finished after 27 timesteps with 26.0 reward 0.9604
# Episode finished after 29 timesteps with 28.0 reward 0.9603
# Episode finished after 17 timesteps with 16.0 reward 0.9601999999999999
# Episode finished after 20 timesteps with 19.0 reward 0.9601
# Episode finished after 12 timesteps with 11.0 reward 0.96
# Episode finished after 35 timesteps with 34.0 reward 0.9599
# Episode finished after 15 timesteps with 14.0 reward 0.9598
# Episode finished after 16 timesteps with 15.0 reward 0.9597
# Episode finished after 27 timesteps with 26.0 reward 0.9596
# Episode finished after 16 timesteps with 15.0 reward 0.9595
# Episode finished after 19 timesteps with 18.0 reward 0.9594
# Episode finished after 12 timesteps with 11.0 reward 0.9593
# Episode finished after 15 timesteps with 14.0 reward 0.9591999999999999
# Episode finished after 21 timesteps with 20.0 reward 0.9591
# Episode finished after 12 timesteps with 11.0 reward 0.959
# Episode finished after 15 timesteps with 14.0 reward 0.9589
# Episode finished after 27 timesteps with 26.0 reward 0.9588
# Episode finished after 45 timesteps with 44.0 reward 0.9587
# Episode finished after 14 timesteps with 13.0 reward 0.9586
# Episode finished after 16 timesteps with 15.0 reward 0.9585
# Episode finished after 19 timesteps with 18.0 reward 0.9584
# Episode finished after 12 timesteps with 11.0 reward 0.9583
# Episode finished after 10 timesteps with 9.0 reward 0.9581999999999999
# Episode finished after 26 timesteps with 25.0 reward 0.9581
# Episode finished after 18 timesteps with 17.0 reward 0.958
# Episode finished after 30 timesteps with 29.0 reward 0.9579
# Episode finished after 17 timesteps with 16.0 reward 0.9578
# Episode finished after 51 timesteps with 50.0 reward 0.9577
# Episode finished after 17 timesteps with 16.0 reward 0.9576
# Episode finished after 12 timesteps with 11.0 reward 0.9575
# Episode finished after 11 timesteps with 10.0 reward 0.9574
# Episode finished after 18 timesteps with 17.0 reward 0.9573
# Episode finished after 15 timesteps with 14.0 reward 0.9571999999999999
# Episode finished after 12 timesteps with 11.0 reward 0.9571
# Episode finished after 22 timesteps with 21.0 reward 0.957
# Episode finished after 15 timesteps with 14.0 reward 0.9569
# Episode finished after 15 timesteps with 14.0 reward 0.9568
# Episode finished after 23 timesteps with 22.0 reward 0.9567
# Episode finished after 16 timesteps with 15.0 reward 0.9566
# Episode finished after 29 timesteps with 28.0 reward 0.9565
# Episode finished after 37 timesteps with 36.0 reward 0.9564
# Episode finished after 28 timesteps with 27.0 reward 0.9563
# Episode finished after 24 timesteps with 23.0 reward 0.9561999999999999
# Episode finished after 35 timesteps with 34.0 reward 0.9561
# Episode finished after 18 timesteps with 17.0 reward 0.956
# Episode finished after 12 timesteps with 11.0 reward 0.9559
# Episode finished after 20 timesteps with 19.0 reward 0.9558
# Episode finished after 67 timesteps with 66.0 reward 0.9557
# Episode finished after 32 timesteps with 31.0 reward 0.9556
# Episode finished after 14 timesteps with 13.0 reward 0.9555
# Episode finished after 43 timesteps with 42.0 reward 0.9554
# Episode finished after 40 timesteps with 39.0 reward 0.9553
# Episode finished after 18 timesteps with 17.0 reward 0.9552
# Episode finished after 48 timesteps with 47.0 reward 0.9551
# Episode finished after 28 timesteps with 27.0 reward 0.955
# Episode finished after 23 timesteps with 22.0 reward 0.9549
# Episode finished after 60 timesteps with 59.0 reward 0.9548
# Episode finished after 19 timesteps with 18.0 reward 0.9547
# Episode finished after 14 timesteps with 13.0 reward 0.9546
# Episode finished after 18 timesteps with 17.0 reward 0.9545
# Episode finished after 28 timesteps with 27.0 reward 0.9544
# Episode finished after 25 timesteps with 24.0 reward 0.9543
# Episode finished after 17 timesteps with 16.0 reward 0.9541999999999999
# Episode finished after 26 timesteps with 25.0 reward 0.9541
# Episode finished after 15 timesteps with 14.0 reward 0.954
# Episode finished after 15 timesteps with 14.0 reward 0.9539
# Episode finished after 14 timesteps with 13.0 reward 0.9538
# Episode finished after 17 timesteps with 16.0 reward 0.9537
# Episode finished after 20 timesteps with 19.0 reward 0.9536
# Episode finished after 18 timesteps with 17.0 reward 0.9535
# Episode finished after 43 timesteps with 42.0 reward 0.9534
# Episode finished after 12 timesteps with 11.0 reward 0.9533
# Episode finished after 11 timesteps with 10.0 reward 0.9532
# Episode finished after 14 timesteps with 13.0 reward 0.9531
# Episode finished after 25 timesteps with 24.0 reward 0.953
# Episode finished after 19 timesteps with 18.0 reward 0.9529
# Episode finished after 10 timesteps with 9.0 reward 0.9528
# Episode finished after 24 timesteps with 23.0 reward 0.9527
# Episode finished after 16 timesteps with 15.0 reward 0.9526
# Episode finished after 48 timesteps with 47.0 reward 0.9525
# Episode finished after 55 timesteps with 54.0 reward 0.9524
# Episode finished after 19 timesteps with 18.0 reward 0.9523
# Episode finished after 52 timesteps with 51.0 reward 0.9521999999999999
# Episode finished after 31 timesteps with 30.0 reward 0.9521
# Episode finished after 25 timesteps with 24.0 reward 0.952
# Episode finished after 29 timesteps with 28.0 reward 0.9519
# Episode finished after 23 timesteps with 22.0 reward 0.9518
# Episode finished after 35 timesteps with 34.0 reward 0.9517
# Episode finished after 27 timesteps with 26.0 reward 0.9516
# Episode finished after 16 timesteps with 15.0 reward 0.9515
# Episode finished after 23 timesteps with 22.0 reward 0.9514
# Episode finished after 11 timesteps with 10.0 reward 0.9513
# Episode finished after 22 timesteps with 21.0 reward 0.9512
# Episode finished after 39 timesteps with 38.0 reward 0.9511
# Episode finished after 28 timesteps with 27.0 reward 0.951
# Episode finished after 12 timesteps with 11.0 reward 0.9509
# Episode finished after 17 timesteps with 16.0 reward 0.9508
# Episode finished after 15 timesteps with 14.0 reward 0.9507
# Episode finished after 18 timesteps with 17.0 reward 0.9506
# Episode finished after 30 timesteps with 29.0 reward 0.9505
# Episode finished after 21 timesteps with 20.0 reward 0.9504
# Episode finished after 28 timesteps with 27.0 reward 0.9503
# Episode finished after 15 timesteps with 14.0 reward 0.9501999999999999
# Episode finished after 29 timesteps with 28.0 reward 0.9501
# Episode finished after 16 timesteps with 15.0 reward 0.95
# Episode finished after 12 timesteps with 11.0 reward 0.9499
# Episode finished after 23 timesteps with 22.0 reward 0.9498
# Episode finished after 21 timesteps with 20.0 reward 0.9497
# Episode finished after 10 timesteps with 9.0 reward 0.9496
# Episode finished after 16 timesteps with 15.0 reward 0.9495
# Episode finished after 31 timesteps with 30.0 reward 0.9494
# Episode finished after 19 timesteps with 18.0 reward 0.9493
# Episode finished after 16 timesteps with 15.0 reward 0.9492
# Episode finished after 14 timesteps with 13.0 reward 0.9490999999999999
# Episode finished after 18 timesteps with 17.0 reward 0.949
# Episode finished after 26 timesteps with 25.0 reward 0.9489
# Episode finished after 9 timesteps with 8.0 reward 0.9488
# Episode finished after 23 timesteps with 22.0 reward 0.9487
# Episode finished after 13 timesteps with 12.0 reward 0.9486
# Episode finished after 13 timesteps with 12.0 reward 0.9485
# Episode finished after 11 timesteps with 10.0 reward 0.9484
# Episode finished after 17 timesteps with 16.0 reward 0.9483
# Episode finished after 11 timesteps with 10.0 reward 0.9482
# Episode finished after 18 timesteps with 17.0 reward 0.9480999999999999
# Episode finished after 20 timesteps with 19.0 reward 0.948
# Episode finished after 20 timesteps with 19.0 reward 0.9479
# Episode finished after 11 timesteps with 10.0 reward 0.9478
# Episode finished after 14 timesteps with 13.0 reward 0.9477
# Episode finished after 27 timesteps with 26.0 reward 0.9476
# Episode finished after 32 timesteps with 31.0 reward 0.9475
# Episode finished after 29 timesteps with 28.0 reward 0.9474
# Episode finished after 10 timesteps with 9.0 reward 0.9473
# Episode finished after 19 timesteps with 18.0 reward 0.9472
# Episode finished after 14 timesteps with 13.0 reward 0.9470999999999999
# Episode finished after 10 timesteps with 9.0 reward 0.947
# Episode finished after 26 timesteps with 25.0 reward 0.9469
# Episode finished after 23 timesteps with 22.0 reward 0.9468
# Episode finished after 67 timesteps with 66.0 reward 0.9467
# Episode finished after 9 timesteps with 8.0 reward 0.9466
# Episode finished after 29 timesteps with 28.0 reward 0.9465
# Episode finished after 22 timesteps with 21.0 reward 0.9464
# Episode finished after 24 timesteps with 23.0 reward 0.9463
# Episode finished after 22 timesteps with 21.0 reward 0.9462
# Episode finished after 24 timesteps with 23.0 reward 0.9460999999999999
# Episode finished after 23 timesteps with 22.0 reward 0.946
# Episode finished after 19 timesteps with 18.0 reward 0.9459
# Episode finished after 53 timesteps with 52.0 reward 0.9458
# Episode finished after 12 timesteps with 11.0 reward 0.9457
# Episode finished after 16 timesteps with 15.0 reward 0.9456
# Episode finished after 13 timesteps with 12.0 reward 0.9455
# Episode finished after 39 timesteps with 38.0 reward 0.9454
# Episode finished after 17 timesteps with 16.0 reward 0.9453
# Episode finished after 29 timesteps with 28.0 reward 0.9452
# Episode finished after 26 timesteps with 25.0 reward 0.9450999999999999
# Episode finished after 21 timesteps with 20.0 reward 0.945
# Episode finished after 18 timesteps with 17.0 reward 0.9449
# Episode finished after 45 timesteps with 44.0 reward 0.9448
# Episode finished after 13 timesteps with 12.0 reward 0.9447
# Episode finished after 29 timesteps with 28.0 reward 0.9446
# Episode finished after 24 timesteps with 23.0 reward 0.9445
# Episode finished after 12 timesteps with 11.0 reward 0.9444
# Episode finished after 17 timesteps with 16.0 reward 0.9443
# Episode finished after 16 timesteps with 15.0 reward 0.9442
# Episode finished after 15 timesteps with 14.0 reward 0.9440999999999999
# Episode finished after 17 timesteps with 16.0 reward 0.944
# Episode finished after 16 timesteps with 15.0 reward 0.9439
# Episode finished after 15 timesteps with 14.0 reward 0.9438
# Episode finished after 61 timesteps with 60.0 reward 0.9437
# Episode finished after 22 timesteps with 21.0 reward 0.9436
# Episode finished after 51 timesteps with 50.0 reward 0.9435
# Episode finished after 25 timesteps with 24.0 reward 0.9434
# Episode finished after 30 timesteps with 29.0 reward 0.9433
# Episode finished after 27 timesteps with 26.0 reward 0.9432
# Episode finished after 22 timesteps with 21.0 reward 0.9431
# Episode finished after 15 timesteps with 14.0 reward 0.943
# Episode finished after 29 timesteps with 28.0 reward 0.9429
# Episode finished after 32 timesteps with 31.0 reward 0.9428
# Episode finished after 30 timesteps with 29.0 reward 0.9427
# Episode finished after 12 timesteps with 11.0 reward 0.9426
# Episode finished after 19 timesteps with 18.0 reward 0.9425
# Episode finished after 42 timesteps with 41.0 reward 0.9424
# Episode finished after 31 timesteps with 30.0 reward 0.9423
# Episode finished after 22 timesteps with 21.0 reward 0.9422
# Episode finished after 15 timesteps with 14.0 reward 0.9420999999999999
# Episode finished after 18 timesteps with 17.0 reward 0.942
# Episode finished after 16 timesteps with 15.0 reward 0.9419
# Episode finished after 24 timesteps with 23.0 reward 0.9418
# Episode finished after 24 timesteps with 23.0 reward 0.9417
# Episode finished after 25 timesteps with 24.0 reward 0.9416
# Episode finished after 18 timesteps with 17.0 reward 0.9415
# Episode finished after 14 timesteps with 13.0 reward 0.9414
# Episode finished after 29 timesteps with 28.0 reward 0.9413
# Episode finished after 19 timesteps with 18.0 reward 0.9412
# Episode finished after 27 timesteps with 26.0 reward 0.9411
# Episode finished after 16 timesteps with 15.0 reward 0.941
# Episode finished after 17 timesteps with 16.0 reward 0.9409
# Episode finished after 27 timesteps with 26.0 reward 0.9408
# Episode finished after 42 timesteps with 41.0 reward 0.9407
# Episode finished after 19 timesteps with 18.0 reward 0.9406
# Episode finished after 43 timesteps with 42.0 reward 0.9405
# Episode finished after 15 timesteps with 14.0 reward 0.9404
# Episode finished after 13 timesteps with 12.0 reward 0.9403
# Episode finished after 15 timesteps with 14.0 reward 0.9402
# Episode finished after 11 timesteps with 10.0 reward 0.9400999999999999
# Episode finished after 19 timesteps with 18.0 reward 0.94
# Episode finished after 48 timesteps with 47.0 reward 0.9399
# Episode finished after 24 timesteps with 23.0 reward 0.9398
# Episode finished after 14 timesteps with 13.0 reward 0.9397
# Episode finished after 29 timesteps with 28.0 reward 0.9396
# Episode finished after 23 timesteps with 22.0 reward 0.9395
# Episode finished after 15 timesteps with 14.0 reward 0.9394
# Episode finished after 39 timesteps with 38.0 reward 0.9393
# Episode finished after 12 timesteps with 11.0 reward 0.9392
# Episode finished after 34 timesteps with 33.0 reward 0.9391
# Episode finished after 14 timesteps with 13.0 reward 0.939
# Episode finished after 17 timesteps with 16.0 reward 0.9389
# Episode finished after 15 timesteps with 14.0 reward 0.9388
# Episode finished after 42 timesteps with 41.0 reward 0.9387
# Episode finished after 42 timesteps with 41.0 reward 0.9386
# Episode finished after 12 timesteps with 11.0 reward 0.9385
# Episode finished after 33 timesteps with 32.0 reward 0.9384
# Episode finished after 53 timesteps with 52.0 reward 0.9383
# Episode finished after 11 timesteps with 10.0 reward 0.9382
# Episode finished after 49 timesteps with 48.0 reward 0.9380999999999999
# Episode finished after 20 timesteps with 19.0 reward 0.938
# Episode finished after 11 timesteps with 10.0 reward 0.9379
# Episode finished after 38 timesteps with 37.0 reward 0.9378
# Episode finished after 12 timesteps with 11.0 reward 0.9377
# Episode finished after 15 timesteps with 14.0 reward 0.9376
# Episode finished after 35 timesteps with 34.0 reward 0.9375
# Episode finished after 19 timesteps with 18.0 reward 0.9374
# Episode finished after 12 timesteps with 11.0 reward 0.9373
# Episode finished after 15 timesteps with 14.0 reward 0.9372
# Episode finished after 17 timesteps with 16.0 reward 0.9371
# Episode finished after 70 timesteps with 69.0 reward 0.9369999999999999
# Episode finished after 23 timesteps with 22.0 reward 0.9369
# Episode finished after 11 timesteps with 10.0 reward 0.9368
# Episode finished after 10 timesteps with 9.0 reward 0.9367
# Episode finished after 23 timesteps with 22.0 reward 0.9366
# Episode finished after 18 timesteps with 17.0 reward 0.9365
# Episode finished after 19 timesteps with 18.0 reward 0.9364
# Episode finished after 24 timesteps with 23.0 reward 0.9363
# Episode finished after 12 timesteps with 11.0 reward 0.9362
# Episode finished after 15 timesteps with 14.0 reward 0.9360999999999999
# Episode finished after 13 timesteps with 12.0 reward 0.9359999999999999
# Episode finished after 42 timesteps with 41.0 reward 0.9359
# Episode finished after 10 timesteps with 9.0 reward 0.9358
# Episode finished after 12 timesteps with 11.0 reward 0.9357
# Episode finished after 18 timesteps with 17.0 reward 0.9356
# Episode finished after 23 timesteps with 22.0 reward 0.9355
# Episode finished after 22 timesteps with 21.0 reward 0.9354
# Episode finished after 11 timesteps with 10.0 reward 0.9353
# Episode finished after 35 timesteps with 34.0 reward 0.9352
# Episode finished after 14 timesteps with 13.0 reward 0.9351
# Episode finished after 11 timesteps with 10.0 reward 0.9349999999999999
# Episode finished after 22 timesteps with 21.0 reward 0.9349
# Episode finished after 14 timesteps with 13.0 reward 0.9348
# Episode finished after 42 timesteps with 41.0 reward 0.9347
# Episode finished after 40 timesteps with 39.0 reward 0.9346
# Episode finished after 18 timesteps with 17.0 reward 0.9345
# Episode finished after 37 timesteps with 36.0 reward 0.9344
# Episode finished after 18 timesteps with 17.0 reward 0.9343
# Episode finished after 18 timesteps with 17.0 reward 0.9342
# Episode finished after 46 timesteps with 45.0 reward 0.9341
# Episode finished after 14 timesteps with 13.0 reward 0.9339999999999999
# Episode finished after 14 timesteps with 13.0 reward 0.9339
# Episode finished after 12 timesteps with 11.0 reward 0.9338
# Episode finished after 24 timesteps with 23.0 reward 0.9337
# Episode finished after 11 timesteps with 10.0 reward 0.9336
# Episode finished after 20 timesteps with 19.0 reward 0.9335
# Episode finished after 15 timesteps with 14.0 reward 0.9334
# Episode finished after 27 timesteps with 26.0 reward 0.9333
# Episode finished after 23 timesteps with 22.0 reward 0.9332
# Episode finished after 17 timesteps with 16.0 reward 0.9331
# Episode finished after 12 timesteps with 11.0 reward 0.9329999999999999
# Episode finished after 24 timesteps with 23.0 reward 0.9329
# Episode finished after 14 timesteps with 13.0 reward 0.9328
# Episode finished after 12 timesteps with 11.0 reward 0.9327
# Episode finished after 38 timesteps with 37.0 reward 0.9326
# Episode finished after 42 timesteps with 41.0 reward 0.9325
# Episode finished after 35 timesteps with 34.0 reward 0.9324
# Episode finished after 22 timesteps with 21.0 reward 0.9323
# Episode finished after 19 timesteps with 18.0 reward 0.9322
# Episode finished after 71 timesteps with 70.0 reward 0.9321
# Episode finished after 28 timesteps with 27.0 reward 0.9319999999999999
# Episode finished after 13 timesteps with 12.0 reward 0.9319
# Episode finished after 30 timesteps with 29.0 reward 0.9318
# Episode finished after 11 timesteps with 10.0 reward 0.9317
# Episode finished after 14 timesteps with 13.0 reward 0.9316
# Episode finished after 21 timesteps with 20.0 reward 0.9315
# Episode finished after 13 timesteps with 12.0 reward 0.9314
# Episode finished after 28 timesteps with 27.0 reward 0.9313
# Episode finished after 64 timesteps with 63.0 reward 0.9312
# Episode finished after 29 timesteps with 28.0 reward 0.9311
# Episode finished after 16 timesteps with 15.0 reward 0.931
# Episode finished after 19 timesteps with 18.0 reward 0.9309
# Episode finished after 33 timesteps with 32.0 reward 0.9308
# Episode finished after 11 timesteps with 10.0 reward 0.9307
# Episode finished after 36 timesteps with 35.0 reward 0.9306
# Episode finished after 19 timesteps with 18.0 reward 0.9305
# Episode finished after 58 timesteps with 57.0 reward 0.9304
# Episode finished after 25 timesteps with 24.0 reward 0.9303
# Episode finished after 13 timesteps with 12.0 reward 0.9302
# Episode finished after 37 timesteps with 36.0 reward 0.9301
# Episode finished after 20 timesteps with 19.0 reward 0.9299999999999999
# Episode finished after 19 timesteps with 18.0 reward 0.9299
# Episode finished after 32 timesteps with 31.0 reward 0.9298
# Episode finished after 12 timesteps with 11.0 reward 0.9297
# Episode finished after 24 timesteps with 23.0 reward 0.9296
# Episode finished after 12 timesteps with 11.0 reward 0.9295
# Episode finished after 20 timesteps with 19.0 reward 0.9294
# Episode finished after 33 timesteps with 32.0 reward 0.9293
# Episode finished after 16 timesteps with 15.0 reward 0.9292
# Episode finished after 20 timesteps with 19.0 reward 0.9291
# Episode finished after 13 timesteps with 12.0 reward 0.929
# Episode finished after 21 timesteps with 20.0 reward 0.9289
# Episode finished after 18 timesteps with 17.0 reward 0.9288
# Episode finished after 27 timesteps with 26.0 reward 0.9287
# Episode finished after 18 timesteps with 17.0 reward 0.9286
# Episode finished after 12 timesteps with 11.0 reward 0.9285
# Episode finished after 44 timesteps with 43.0 reward 0.9284
# Episode finished after 23 timesteps with 22.0 reward 0.9283
# Episode finished after 20 timesteps with 19.0 reward 0.9282
# Episode finished after 20 timesteps with 19.0 reward 0.9281
# Episode finished after 21 timesteps with 20.0 reward 0.9279999999999999
# Episode finished after 62 timesteps with 61.0 reward 0.9279
# Episode finished after 32 timesteps with 31.0 reward 0.9278
# Episode finished after 16 timesteps with 15.0 reward 0.9277
# Episode finished after 27 timesteps with 26.0 reward 0.9276
# Episode finished after 14 timesteps with 13.0 reward 0.9275
# Episode finished after 23 timesteps with 22.0 reward 0.9274
# Episode finished after 23 timesteps with 22.0 reward 0.9273
# Episode finished after 17 timesteps with 16.0 reward 0.9272
# Episode finished after 23 timesteps with 22.0 reward 0.9271
# Episode finished after 31 timesteps with 30.0 reward 0.927
# Episode finished after 13 timesteps with 12.0 reward 0.9269
# Episode finished after 13 timesteps with 12.0 reward 0.9268
# Episode finished after 15 timesteps with 14.0 reward 0.9267
# Episode finished after 16 timesteps with 15.0 reward 0.9266
# Episode finished after 14 timesteps with 13.0 reward 0.9265
# Episode finished after 24 timesteps with 23.0 reward 0.9264
# Episode finished after 10 timesteps with 9.0 reward 0.9263
# Episode finished after 46 timesteps with 45.0 reward 0.9262
# Episode finished after 16 timesteps with 15.0 reward 0.9261
# Episode finished after 25 timesteps with 24.0 reward 0.9259999999999999
# Episode finished after 17 timesteps with 16.0 reward 0.9259
# Episode finished after 11 timesteps with 10.0 reward 0.9258
# Episode finished after 16 timesteps with 15.0 reward 0.9257
# Episode finished after 76 timesteps with 75.0 reward 0.9256
# Episode finished after 22 timesteps with 21.0 reward 0.9255
# Episode finished after 12 timesteps with 11.0 reward 0.9254
# Episode finished after 15 timesteps with 14.0 reward 0.9253
# Episode finished after 11 timesteps with 10.0 reward 0.9252
# Episode finished after 11 timesteps with 10.0 reward 0.9251
# Episode finished after 19 timesteps with 18.0 reward 0.925
# Episode finished after 28 timesteps with 27.0 reward 0.9248999999999999
# Episode finished after 11 timesteps with 10.0 reward 0.9248
# Episode finished after 16 timesteps with 15.0 reward 0.9247
# Episode finished after 30 timesteps with 29.0 reward 0.9246
# Episode finished after 14 timesteps with 13.0 reward 0.9245
# Episode finished after 18 timesteps with 17.0 reward 0.9244
# Episode finished after 13 timesteps with 12.0 reward 0.9243
# Episode finished after 69 timesteps with 68.0 reward 0.9242
# Episode finished after 13 timesteps with 12.0 reward 0.9241
# Episode finished after 22 timesteps with 21.0 reward 0.9239999999999999
# Episode finished after 21 timesteps with 20.0 reward 0.9238999999999999
# Episode finished after 21 timesteps with 20.0 reward 0.9238
# Episode finished after 13 timesteps with 12.0 reward 0.9237
# Episode finished after 23 timesteps with 22.0 reward 0.9236
# Episode finished after 25 timesteps with 24.0 reward 0.9235
# Episode finished after 23 timesteps with 22.0 reward 0.9234
# Episode finished after 16 timesteps with 15.0 reward 0.9233
# Episode finished after 37 timesteps with 36.0 reward 0.9232
# Episode finished after 14 timesteps with 13.0 reward 0.9231
# Episode finished after 14 timesteps with 13.0 reward 0.923
# Episode finished after 56 timesteps with 55.0 reward 0.9228999999999999
# Episode finished after 42 timesteps with 41.0 reward 0.9228
# Episode finished after 34 timesteps with 33.0 reward 0.9227
# Episode finished after 22 timesteps with 21.0 reward 0.9226
# Episode finished after 16 timesteps with 15.0 reward 0.9225
# Episode finished after 15 timesteps with 14.0 reward 0.9224
# Episode finished after 25 timesteps with 24.0 reward 0.9223
# Episode finished after 17 timesteps with 16.0 reward 0.9222
# Episode finished after 22 timesteps with 21.0 reward 0.9221
# Episode finished after 22 timesteps with 21.0 reward 0.9219999999999999
# Episode finished after 12 timesteps with 11.0 reward 0.9218999999999999
# Episode finished after 15 timesteps with 14.0 reward 0.9218
# Episode finished after 10 timesteps with 9.0 reward 0.9217
# Episode finished after 16 timesteps with 15.0 reward 0.9216
# Episode finished after 20 timesteps with 19.0 reward 0.9215
# Episode finished after 29 timesteps with 28.0 reward 0.9214
# Episode finished after 17 timesteps with 16.0 reward 0.9213
# Episode finished after 36 timesteps with 35.0 reward 0.9212
# Episode finished after 14 timesteps with 13.0 reward 0.9211
# Episode finished after 36 timesteps with 35.0 reward 0.921
# Episode finished after 23 timesteps with 22.0 reward 0.9209
# Episode finished after 18 timesteps with 17.0 reward 0.9208
# Episode finished after 27 timesteps with 26.0 reward 0.9207
# Episode finished after 15 timesteps with 14.0 reward 0.9206
# Episode finished after 15 timesteps with 14.0 reward 0.9205
# Episode finished after 15 timesteps with 14.0 reward 0.9204
# Episode finished after 20 timesteps with 19.0 reward 0.9203
# Episode finished after 21 timesteps with 20.0 reward 0.9202
# Episode finished after 22 timesteps with 21.0 reward 0.9201
# Episode finished after 13 timesteps with 12.0 reward 0.9199999999999999
# Episode finished after 24 timesteps with 23.0 reward 0.9198999999999999
# Episode finished after 43 timesteps with 42.0 reward 0.9198
# Episode finished after 16 timesteps with 15.0 reward 0.9197
# Episode finished after 33 timesteps with 32.0 reward 0.9196
# Episode finished after 13 timesteps with 12.0 reward 0.9195
# Episode finished after 13 timesteps with 12.0 reward 0.9194
# Episode finished after 26 timesteps with 25.0 reward 0.9193
# Episode finished after 17 timesteps with 16.0 reward 0.9192
# Episode finished after 17 timesteps with 16.0 reward 0.9191
# Episode finished after 27 timesteps with 26.0 reward 0.919
# Episode finished after 16 timesteps with 15.0 reward 0.9189
# Episode finished after 12 timesteps with 11.0 reward 0.9188
# Episode finished after 26 timesteps with 25.0 reward 0.9187
# Episode finished after 22 timesteps with 21.0 reward 0.9186
# Episode finished after 30 timesteps with 29.0 reward 0.9185
# Episode finished after 19 timesteps with 18.0 reward 0.9184
# Episode finished after 15 timesteps with 14.0 reward 0.9183
# Episode finished after 32 timesteps with 31.0 reward 0.9182
# Episode finished after 11 timesteps with 10.0 reward 0.9181
# Episode finished after 18 timesteps with 17.0 reward 0.918
# Episode finished after 41 timesteps with 40.0 reward 0.9178999999999999
# Episode finished after 32 timesteps with 31.0 reward 0.9178
# Episode finished after 15 timesteps with 14.0 reward 0.9177
# Episode finished after 17 timesteps with 16.0 reward 0.9176
# Episode finished after 9 timesteps with 8.0 reward 0.9175
# Episode finished after 52 timesteps with 51.0 reward 0.9174
# Episode finished after 13 timesteps with 12.0 reward 0.9173
# Episode finished after 20 timesteps with 19.0 reward 0.9172
# Episode finished after 23 timesteps with 22.0 reward 0.9171
# Episode finished after 19 timesteps with 18.0 reward 0.917
# Episode finished after 27 timesteps with 26.0 reward 0.9169
# Episode finished after 12 timesteps with 11.0 reward 0.9168
# Episode finished after 12 timesteps with 11.0 reward 0.9167
# Episode finished after 14 timesteps with 13.0 reward 0.9166
# Episode finished after 22 timesteps with 21.0 reward 0.9165
# Episode finished after 27 timesteps with 26.0 reward 0.9164
# Episode finished after 16 timesteps with 15.0 reward 0.9163
# Episode finished after 9 timesteps with 8.0 reward 0.9162
# Episode finished after 59 timesteps with 58.0 reward 0.9161
# Episode finished after 16 timesteps with 15.0 reward 0.916
# Episode finished after 10 timesteps with 9.0 reward 0.9158999999999999
# Episode finished after 24 timesteps with 23.0 reward 0.9158
# Episode finished after 12 timesteps with 11.0 reward 0.9157
# Episode finished after 12 timesteps with 11.0 reward 0.9156
# Episode finished after 14 timesteps with 13.0 reward 0.9155
# Episode finished after 15 timesteps with 14.0 reward 0.9154
# Episode finished after 35 timesteps with 34.0 reward 0.9153
# Episode finished after 17 timesteps with 16.0 reward 0.9152
# Episode finished after 14 timesteps with 13.0 reward 0.9151
# Episode finished after 31 timesteps with 30.0 reward 0.915
# Episode finished after 19 timesteps with 18.0 reward 0.9149
# Episode finished after 22 timesteps with 21.0 reward 0.9148
# Episode finished after 16 timesteps with 15.0 reward 0.9147
# Episode finished after 37 timesteps with 36.0 reward 0.9146
# Episode finished after 42 timesteps with 41.0 reward 0.9145
# Episode finished after 19 timesteps with 18.0 reward 0.9144
# Episode finished after 10 timesteps with 9.0 reward 0.9143
# Episode finished after 29 timesteps with 28.0 reward 0.9142
# Episode finished after 25 timesteps with 24.0 reward 0.9141
# Episode finished after 55 timesteps with 54.0 reward 0.914
# Episode finished after 14 timesteps with 13.0 reward 0.9138999999999999
# Episode finished after 15 timesteps with 14.0 reward 0.9138
# Episode finished after 13 timesteps with 12.0 reward 0.9137
# Episode finished after 12 timesteps with 11.0 reward 0.9136
# Episode finished after 15 timesteps with 14.0 reward 0.9135
# Episode finished after 25 timesteps with 24.0 reward 0.9134
# Episode finished after 21 timesteps with 20.0 reward 0.9133
# Episode finished after 38 timesteps with 37.0 reward 0.9132
# Episode finished after 18 timesteps with 17.0 reward 0.9131
# Episode finished after 31 timesteps with 30.0 reward 0.913
# Episode finished after 22 timesteps with 21.0 reward 0.9129
# Episode finished after 17 timesteps with 16.0 reward 0.9128
# Episode finished after 20 timesteps with 19.0 reward 0.9127
# Episode finished after 20 timesteps with 19.0 reward 0.9126
# Episode finished after 21 timesteps with 20.0 reward 0.9125
# Episode finished after 20 timesteps with 19.0 reward 0.9124
# Episode finished after 48 timesteps with 47.0 reward 0.9123
# Episode finished after 13 timesteps with 12.0 reward 0.9122
# Episode finished after 11 timesteps with 10.0 reward 0.9121
# Episode finished after 11 timesteps with 10.0 reward 0.912
# Episode finished after 44 timesteps with 43.0 reward 0.9118999999999999
# Episode finished after 14 timesteps with 13.0 reward 0.9117999999999999
# Episode finished after 11 timesteps with 10.0 reward 0.9117
# Episode finished after 29 timesteps with 28.0 reward 0.9116
# Episode finished after 16 timesteps with 15.0 reward 0.9115
# Episode finished after 13 timesteps with 12.0 reward 0.9114
# Episode finished after 8 timesteps with 7.0 reward 0.9113
# ...
# 200 successfull movements 99578
# 200 successfull movements 99579
# 200 successfull movements 99580
# Episode finished after 200 timesteps with 199.0 reward 0.05
# 200 successfull movements 99581
# 200 successfull movements 99582
# 200 successfull movements 99583
# 200 successfull movements 99584
# 200 successfull movements 99585
# 200 successfull movements 99586
# 200 successfull movements 99587
# 200 successfull movements 99588
# 200 successfull movements 99589
# 200 successfull movements 99590
# Episode finished after 200 timesteps with 199.0 reward 0.05
# 200 successfull movements 99591
# 200 successfull movements 99592
# 200 successfull movements 99593
# 200 successfull movements 99594
# 200 successfull movements 99595
# 200 successfull movements 99596
# 200 successfull movements 99597
# 200 successfull movements 99598
# 200 successfull movements 99599
# 200 successfull movements 99600
# Episode finished after 200 timesteps with 199.0 reward 0.05
# 200 successfull movements 99601
# 200 successfull movements 99602
# 200 successfull movements 99603
# 200 successfull movements 99604
# 200 successfull movements 99605
# 200 successfull movements 99606
# 200 successfull movements 99607
# 200 successfull movements 99608
# 200 successfull movements 99609
# 200 successfull movements 99610
# Episode finished after 200 timesteps with 199.0 reward 0.05
# 200 successfull movements 99611
# 200 successfull movements 99612
# 200 successfull movements 99613
# 200 successfull movements 99614
# 200 successfull movements 99615
# 200 successfull movements 99616
# 200 successfull movements 99617
# 200 successfull movements 99618
# 200 successfull movements 99619
# 200 successfull movements 99620
# Episode finished after 200 timesteps with 199.0 reward 0.05
# 200 successfull movements 99621
# 200 successfull movements 99622
# 200 successfull movements 99623
# 200 successfull movements 99624
# 200 successfull movements 99625
# 200 successfull movements 99626
# 200 successfull movements 99627
# 200 successfull movements 99628
# 200 successfull movements 99629
# 200 successfull movements 99630
# Episode finished after 200 timesteps with 199.0 reward 0.05
# 200 successfull movements 99631
# 200 successfull movements 99632
# 200 successfull movements 99633
# 200 successfull movements 99634
# 200 successfull movements 99635
# 200 successfull movements 99636
# 200 successfull movements 99637
# 200 successfull movements 99638
# 200 successfull movements 99639
# 200 successfull movements 99640
# Episode finished after 200 timesteps with 199.0 reward 0.05
# 200 successfull movements 99641
# 200 successfull movements 99642
# 200 successfull movements 99643
# 200 successfull movements 99644
# 200 successfull movements 99645
# 200 successfull movements 99646
# 200 successfull movements 99647
# 200 successfull movements 99648
# 200 successfull movements 99649
# 200 successfull movements 99650
# Episode finished after 200 timesteps with 199.0 reward 0.05
# 200 successfull movements 99651
# 200 successfull movements 99652
# 200 successfull movements 99653
# 200 successfull movements 99654
# 200 successfull movements 99655
# 200 successfull movements 99656
# 200 successfull movements 99657
# 200 successfull movements 99658
# 200 successfull movements 99659
# 200 successfull movements 99660
# Episode finished after 200 timesteps with 199.0 reward 0.05
# 200 successfull movements 99661
# 200 successfull movements 99662
# 200 successfull movements 99663
# 200 successfull movements 99664
# 200 successfull movements 99665
# 200 successfull movements 99666
# 200 successfull movements 99667
# 200 successfull movements 99668
# 200 successfull movements 99669
# 200 successfull movements 99670
# Episode finished after 200 timesteps with 199.0 reward 0.05
# 200 successfull movements 99671
# 200 successfull movements 99672
# 200 successfull movements 99673
# 200 successfull movements 99674
# 200 successfull movements 99675
# 200 successfull movements 99676
# 200 successfull movements 99677
# 200 successfull movements 99678
# 200 successfull movements 99679
# 200 successfull movements 99680
# Episode finished after 200 timesteps with 199.0 reward 0.05
# 200 successfull movements 99681
# 200 successfull movements 99682
# 200 successfull movements 99683
# 200 successfull movements 99684
# 200 successfull movements 99686
# 200 successfull movements 99687
# 200 successfull movements 99688
# 200 successfull movements 99689
# 200 successfull movements 99690
# Episode finished after 200 timesteps with 199.0 reward 0.05
# 200 successfull movements 99691
# 200 successfull movements 99692
# 200 successfull movements 99693
# 200 successfull movements 99694
# 200 successfull movements 99695
# 200 successfull movements 99696
# 200 successfull movements 99697
# 200 successfull movements 99698
# 200 successfull movements 99699
# 200 successfull movements 99700
# Episode finished after 200 timesteps with 199.0 reward 0.05
# 200 successfull movements 99701
# 200 successfull movements 99702
# 200 successfull movements 99703
# 200 successfull movements 99704
# 200 successfull movements 99705
# 200 successfull movements 99706
# 200 successfull movements 99707
# 200 successfull movements 99708
# 200 successfull movements 99709
# 200 successfull movements 99710
# Episode finished after 200 timesteps with 199.0 reward 0.05
# 200 successfull movements 99711
# 200 successfull movements 99712
# 200 successfull movements 99713
# 200 successfull movements 99714
# 200 successfull movements 99715
# 200 successfull movements 99716
# 200 successfull movements 99717
# 200 successfull movements 99718
# 200 successfull movements 99719
# 200 successfull movements 99720
# Episode finished after 200 timesteps with 199.0 reward 0.05
# 200 successfull movements 99721
# 200 successfull movements 99722
# 200 successfull movements 99723
# 200 successfull movements 99724
# 200 successfull movements 99726
# 200 successfull movements 99727
# 200 successfull movements 99728
# 200 successfull movements 99729
# 200 successfull movements 99730
# Episode finished after 200 timesteps with 199.0 reward 0.05
# 200 successfull movements 99731
# 200 successfull movements 99732
# 200 successfull movements 99733
# 200 successfull movements 99734
# 200 successfull movements 99735
# 200 successfull movements 99736
# 200 successfull movements 99737
# 200 successfull movements 99738
# 200 successfull movements 99739
# 200 successfull movements 99740
# Episode finished after 200 timesteps with 199.0 reward 0.05
# 200 successfull movements 99741
# 200 successfull movements 99742
# 200 successfull movements 99743
# 200 successfull movements 99744
# 200 successfull movements 99745
# 200 successfull movements 99746
# 200 successfull movements 99747
# 200 successfull movements 99748
# 200 successfull movements 99749
# 200 successfull movements 99750
# Episode finished after 200 timesteps with 199.0 reward 0.05
# 200 successfull movements 99751
# 200 successfull movements 99752
# 200 successfull movements 99753
# 200 successfull movements 99754
# 200 successfull movements 99755
# 200 successfull movements 99756
# 200 successfull movements 99757
# 200 successfull movements 99758
# 200 successfull movements 99759
# 200 successfull movements 99760
# Episode finished after 200 timesteps with 199.0 reward 0.05
# 200 successfull movements 99761
# 200 successfull movements 99762
# 200 successfull movements 99763
# 200 successfull movements 99764
# 200 successfull movements 99765
# 200 successfull movements 99766
# 200 successfull movements 99767
# 200 successfull movements 99768
# 200 successfull movements 99769
# 200 successfull movements 99770
# Episode finished after 200 timesteps with 199.0 reward 0.05
# 200 successfull movements 99771
# 200 successfull movements 99772
# 200 successfull movements 99773
# 200 successfull movements 99774
# 200 successfull movements 99775
# 200 successfull movements 99776
# 200 successfull movements 99777
# 200 successfull movements 99778
# 200 successfull movements 99779
# 200 successfull movements 99780
# Episode finished after 200 timesteps with 199.0 reward 0.05
# 200 successfull movements 99781
# 200 successfull movements 99782
# 200 successfull movements 99783
# 200 successfull movements 99784
# 200 successfull movements 99785
# 200 successfull movements 99786
# 200 successfull movements 99787
# 200 successfull movements 99788
# 200 successfull movements 99789
# 200 successfull movements 99790
# Episode finished after 200 timesteps with 199.0 reward 0.05
# 200 successfull movements 99791
# 200 successfull movements 99792
# 200 successfull movements 99793
# 200 successfull movements 99794
# 200 successfull movements 99795
# 200 successfull movements 99796
# 200 successfull movements 99797
# 200 successfull movements 99798
# 200 successfull movements 99799
# 200 successfull movements 99800
# Episode finished after 200 timesteps with 199.0 reward 0.05
# 200 successfull movements 99801
# 200 successfull movements 99802
# 200 successfull movements 99803
# 200 successfull movements 99804
# 200 successfull movements 99805
# 200 successfull movements 99806
# 200 successfull movements 99807
# 200 successfull movements 99808
# 200 successfull movements 99809
# 200 successfull movements 99810
# Episode finished after 200 timesteps with 199.0 reward 0.05
# 200 successfull movements 99811
# 200 successfull movements 99812
# 200 successfull movements 99813
# 200 successfull movements 99814
# 200 successfull movements 99815
# 200 successfull movements 99816
# 200 successfull movements 99817
# 200 successfull movements 99818
# 200 successfull movements 99819
# 200 successfull movements 99820
# Episode finished after 200 timesteps with 199.0 reward 0.05
# 200 successfull movements 99821
# 200 successfull movements 99822
# 200 successfull movements 99823
# 200 successfull movements 99824
# 200 successfull movements 99825
# 200 successfull movements 99826
# 200 successfull movements 99827
# 200 successfull movements 99828
# 200 successfull movements 99829
# 200 successfull movements 99830
# Episode finished after 200 timesteps with 199.0 reward 0.05
# 200 successfull movements 99831
# 200 successfull movements 99832
# 200 successfull movements 99833
# 200 successfull movements 99834
# 200 successfull movements 99835
# 200 successfull movements 99836
# 200 successfull movements 99837
# 200 successfull movements 99838
# 200 successfull movements 99839
# 200 successfull movements 99840
# Episode finished after 200 timesteps with 199.0 reward 0.05
# 200 successfull movements 99841
# 200 successfull movements 99842
# 200 successfull movements 99843
# 200 successfull movements 99844
# 200 successfull movements 99845
# 200 successfull movements 99846
# 200 successfull movements 99847
# 200 successfull movements 99848
# 200 successfull movements 99849
# 200 successfull movements 99850
# Episode finished after 200 timesteps with 199.0 reward 0.05
# 200 successfull movements 99851
# 200 successfull movements 99852
# 200 successfull movements 99853
# 200 successfull movements 99854
# 200 successfull movements 99855
# 200 successfull movements 99856
# 200 successfull movements 99857
# 200 successfull movements 99858
# 200 successfull movements 99859
# 200 successfull movements 99860
# Episode finished after 200 timesteps with 199.0 reward 0.05
# 200 successfull movements 99861
# 200 successfull movements 99862
# 200 successfull movements 99863
# 200 successfull movements 99864
# 200 successfull movements 99865
# 200 successfull movements 99866
# 200 successfull movements 99867
# 200 successfull movements 99868
# 200 successfull movements 99869
# 200 successfull movements 99870
# Episode finished after 200 timesteps with 199.0 reward 0.05
# 200 successfull movements 99871
# 200 successfull movements 99872
# 200 successfull movements 99873
# 200 successfull movements 99874
# 200 successfull movements 99875
# 200 successfull movements 99876
# 200 successfull movements 99877
# 200 successfull movements 99878
# 200 successfull movements 99879
# 200 successfull movements 99880
# Episode finished after 200 timesteps with 199.0 reward 0.05
# 200 successfull movements 99881
# 200 successfull movements 99882
# 200 successfull movements 99883
# 200 successfull movements 99884
# 200 successfull movements 99885
# 200 successfull movements 99886
# 200 successfull movements 99887
# 200 successfull movements 99888
# 200 successfull movements 99889
# 200 successfull movements 99890
# Episode finished after 200 timesteps with 199.0 reward 0.05
# 200 successfull movements 99891
# 200 successfull movements 99892
# 200 successfull movements 99893
# 200 successfull movements 99894
# 200 successfull movements 99895
# 200 successfull movements 99896
# 200 successfull movements 99897
# 200 successfull movements 99898
# 200 successfull movements 99899
# 200 successfull movements 99900
# Episode finished after 200 timesteps with 199.0 reward 0.05
# 200 successfull movements 99901
# 200 successfull movements 99902
# 200 successfull movements 99903
# 200 successfull movements 99904
# 200 successfull movements 99905
# 200 successfull movements 99906
# 200 successfull movements 99907
# 200 successfull movements 99908
# 200 successfull movements 99909
# 200 successfull movements 99910
# Episode finished after 200 timesteps with 199.0 reward 0.05
# 200 successfull movements 99911
# 200 successfull movements 99912
# 200 successfull movements 99913
# 200 successfull movements 99914
# 200 successfull movements 99915
# 200 successfull movements 99916
# 200 successfull movements 99917
# 200 successfull movements 99918
# 200 successfull movements 99919
# 200 successfull movements 99920
# Episode finished after 200 timesteps with 199.0 reward 0.05
# 200 successfull movements 99921
# 200 successfull movements 99922
# 200 successfull movements 99923
# 200 successfull movements 99924
# 200 successfull movements 99925
# 200 successfull movements 99926
# 200 successfull movements 99927
# 200 successfull movements 99928
# 200 successfull movements 99929
# 200 successfull movements 99930
# Episode finished after 200 timesteps with 199.0 reward 0.05
# 200 successfull movements 99931
# 200 successfull movements 99932
# 200 successfull movements 99933
# 200 successfull movements 99934
# 200 successfull movements 99935
# 200 successfull movements 99936
# 200 successfull movements 99937
# 200 successfull movements 99938
# 200 successfull movements 99939
# 200 successfull movements 99940
# Episode finished after 200 timesteps with 199.0 reward 0.05
# 200 successfull movements 99941
# 200 successfull movements 99942
# 200 successfull movements 99943
# 200 successfull movements 99944
# 200 successfull movements 99945
# 200 successfull movements 99946
# 200 successfull movements 99947
# 200 successfull movements 99948
# 200 successfull movements 99949
# 200 successfull movements 99950
# Episode finished after 200 timesteps with 199.0 reward 0.05
# 200 successfull movements 99951
# 200 successfull movements 99952
# 200 successfull movements 99953
# 200 successfull movements 99954
# 200 successfull movements 99955
# 200 successfull movements 99956
# 200 successfull movements 99957
# 200 successfull movements 99958
# 200 successfull movements 99959
# 200 successfull movements 99960
# Episode finished after 200 timesteps with 199.0 reward 0.05
# 200 successfull movements 99961
# 200 successfull movements 99962
# 200 successfull movements 99963
# 200 successfull movements 99964
# 200 successfull movements 99965
# 200 successfull movements 99966
# 200 successfull movements 99967
# 200 successfull movements 99968
# 200 successfull movements 99969
# 200 successfull movements 99970
# Episode finished after 200 timesteps with 199.0 reward 0.05
# 200 successfull movements 99971
# 200 successfull movements 99972
# 200 successfull movements 99973
# 200 successfull movements 99974
# 200 successfull movements 99975
# 200 successfull movements 99976
# 200 successfull movements 99977
# 200 successfull movements 99978
# 200 successfull movements 99979
# 200 successfull movements 99980
# Episode finished after 200 timesteps with 199.0 reward 0.05
# 200 successfull movements 99981
# 200 successfull movements 99982
# 200 successfull movements 99983
# 200 successfull movements 99984
# 200 successfull movements 99985
# 200 successfull movements 99986
# 200 successfull movements 99987
# 200 successfull movements 99988
# 200 successfull movements 99989
# 200 successfull movements 99990
# Episode finished after 200 timesteps with 199.0 reward 0.05
# 200 successfull movements 99991
# 200 successfull movements 99992
# 200 successfull movements 99993
# 200 successfull movements 99994
# 200 successfull movements 99995
# 200 successfull movements 99996
# 200 successfull movements 99997
# 200 successfull movements 99998
# 200 successfull movements 99999
# Total Reward: 9428824.0 94.28824

# %%
print(len(Q))
#print(Q)
# Out:
# 29308

# %%
#testing the Q policy. Game is solved if average reward over 100 episodes is greater than 195.
episodes = 100
totalReward = 0
test_list = []
for i_episode in range(episodes):
    observation = env.reset()
    episodeReward = 0

    test_list.append(observation)

    for t in range(300):

        bestReward = 0
        action = env.action_space.sample()
        for possibleAction in [0, 1]:
            temp_state = []
            for i in observation:
                temp_state.append(round(i*observation_round,0))
            temp_state.append(possibleAction)

            possibleReward = Q.get(tuple(temp_state[2:]),0.)
            if(possibleReward > bestReward):
                action = possibleAction
                bestReward = possibleReward
        
        observation, reward, done, info = env.step(action)
        episodeReward += reward

        if done:
            print("Episode finished after {} timesteps with {} reward".format(t+1, episodeReward))
            break
    totalReward += episodeReward

print("Total Reward: {}".format(totalReward), totalReward/episodes)
# Out:
# Episode finished after 200 timesteps with 200.0 reward
# Episode finished after 200 timesteps with 200.0 reward
# Episode finished after 200 timesteps with 200.0 reward
# Episode finished after 200 timesteps with 200.0 reward
# Episode finished after 200 timesteps with 200.0 reward
# Episode finished after 200 timesteps with 200.0 reward
# Episode finished after 200 timesteps with 200.0 reward
# Episode finished after 200 timesteps with 200.0 reward
# Episode finished after 200 timesteps with 200.0 reward
# Episode finished after 200 timesteps with 200.0 reward
# Episode finished after 200 timesteps with 200.0 reward
# Episode finished after 200 timesteps with 200.0 reward
# Episode finished after 200 timesteps with 200.0 reward
# Episode finished after 200 timesteps with 200.0 reward
# Episode finished after 200 timesteps with 200.0 reward
# Episode finished after 200 timesteps with 200.0 reward
# Episode finished after 200 timesteps with 200.0 reward
# Episode finished after 200 timesteps with 200.0 reward
# Episode finished after 200 timesteps with 200.0 reward
# Episode finished after 200 timesteps with 200.0 reward
# Episode finished after 200 timesteps with 200.0 reward
# Episode finished after 200 timesteps with 200.0 reward
# Episode finished after 200 timesteps with 200.0 reward
# Episode finished after 200 timesteps with 200.0 reward
# Episode finished after 200 timesteps with 200.0 reward
# Episode finished after 200 timesteps with 200.0 reward
# Episode finished after 200 timesteps with 200.0 reward
# Episode finished after 200 timesteps with 200.0 reward
# Episode finished after 200 timesteps with 200.0 reward
# Episode finished after 200 timesteps with 200.0 reward
# Episode finished after 200 timesteps with 200.0 reward
# Episode finished after 200 timesteps with 200.0 reward
# Episode finished after 200 timesteps with 200.0 reward
# Episode finished after 200 timesteps with 200.0 reward
# Episode finished after 200 timesteps with 200.0 reward
# Episode finished after 200 timesteps with 200.0 reward
# Episode finished after 200 timesteps with 200.0 reward
# Episode finished after 200 timesteps with 200.0 reward
# Episode finished after 200 timesteps with 200.0 reward
# Episode finished after 200 timesteps with 200.0 reward
# Episode finished after 200 timesteps with 200.0 reward
# Episode finished after 200 timesteps with 200.0 reward
# Episode finished after 200 timesteps with 200.0 reward
# Episode finished after 200 timesteps with 200.0 reward
# Episode finished after 200 timesteps with 200.0 reward
# Episode finished after 200 timesteps with 200.0 reward
# Episode finished after 200 timesteps with 200.0 reward
# Episode finished after 200 timesteps with 200.0 reward
# Episode finished after 200 timesteps with 200.0 reward
# Episode finished after 200 timesteps with 200.0 reward
# Episode finished after 200 timesteps with 200.0 reward
# Episode finished after 200 timesteps with 200.0 reward
# Episode finished after 200 timesteps with 200.0 reward
# Episode finished after 200 timesteps with 200.0 reward
# Episode finished after 200 timesteps with 200.0 reward
# Episode finished after 200 timesteps with 200.0 reward
# Episode finished after 200 timesteps with 200.0 reward
# Episode finished after 200 timesteps with 200.0 reward
# Episode finished after 200 timesteps with 200.0 reward
# Episode finished after 200 timesteps with 200.0 reward
# Episode finished after 200 timesteps with 200.0 reward
# Episode finished after 200 timesteps with 200.0 reward
# Episode finished after 200 timesteps with 200.0 reward
# Episode finished after 200 timesteps with 200.0 reward
# Episode finished after 200 timesteps with 200.0 reward
# Episode finished after 200 timesteps with 200.0 reward
# Episode finished after 200 timesteps with 200.0 reward
# Episode finished after 200 timesteps with 200.0 reward
# Episode finished after 200 timesteps with 200.0 reward
# Episode finished after 200 timesteps with 200.0 reward
# Episode finished after 200 timesteps with 200.0 reward
# Episode finished after 200 timesteps with 200.0 reward
# Episode finished after 200 timesteps with 200.0 reward
# Episode finished after 200 timesteps with 200.0 reward
# Episode finished after 200 timesteps with 200.0 reward
# Episode finished after 200 timesteps with 200.0 reward
# Episode finished after 200 timesteps with 200.0 reward
# Episode finished after 200 timesteps with 200.0 reward
# Episode finished after 200 timesteps with 200.0 reward
# Episode finished after 200 timesteps with 200.0 reward
# Episode finished after 200 timesteps with 200.0 reward
# Episode finished after 200 timesteps with 200.0 reward
# Episode finished after 200 timesteps with 200.0 reward
# Episode finished after 200 timesteps with 200.0 reward
# Episode finished after 200 timesteps with 200.0 reward
# Episode finished after 200 timesteps with 200.0 reward
# Episode finished after 200 timesteps with 200.0 reward
# Episode finished after 200 timesteps with 200.0 reward
# Episode finished after 200 timesteps with 200.0 reward
# Episode finished after 200 timesteps with 200.0 reward
# Episode finished after 200 timesteps with 200.0 reward
# Episode finished after 200 timesteps with 200.0 reward
# Episode finished after 200 timesteps with 200.0 reward
# Episode finished after 200 timesteps with 200.0 reward
# Episode finished after 200 timesteps with 200.0 reward
# Episode finished after 200 timesteps with 200.0 reward
# Episode finished after 200 timesteps with 200.0 reward
# Episode finished after 200 timesteps with 200.0 reward
# Episode finished after 200 timesteps with 200.0 reward
# Episode finished after 200 timesteps with 200.0 reward
# Total Reward: 20000.0 200.0

# %% [markdown]
# # Conclusion
# * Thus the game is solved after 100,000 episodes of training, though the last 50,000 episodes of training were likely superfulous.
# * To improve, would be better to do a periodically test the optimal policy throughout the training to see when exactly the solution was found.
# * Hyperparamters to tune learning rate, episolon start value and decay value
# * There are other methods that can be used to attempt to solve the game.
